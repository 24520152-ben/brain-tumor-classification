# %%
# !pip install focal-loss
# Out:
# Collecting focal-loss
#   Downloading focal_loss-0.0.7-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: tensorflow>=2.2 in /usr/local/lib/python3.11/dist-packages (from focal-loss) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow>=2.2->focal-loss)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (2.32.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (1.74.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.2->focal-loss) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.2->focal-loss) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.2->focal-loss) (14.2.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.2->focal-loss) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.2->focal-loss) (0.16.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.2->focal-loss) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.2->focal-loss) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.2->focal-loss) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.2->focal-loss) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.2->focal-loss) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.2->focal-loss) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.2->focal-loss) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow>=2.2->focal-loss) (3.0.3)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.2->focal-loss) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.2->focal-loss) (2.19.2)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.1.0,>=1.26.0->tensorflow>=2.2->focal-loss) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.2->focal-loss) (0.1.2)
# Downloading focal_loss-0.0.7-py3-none-any.whl (19 kB)
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 19.3 MB/s eta 0:00:00
# Installing collected packages: protobuf, focal-loss
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.0
#     Uninstalling protobuf-6.33.0:
#       Successfully uninstalled protobuf-6.33.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-cloud-translate 3.12.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.29.5 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Successfully installed focal-loss-0.0.7 protobuf-5.29.5

# %%
import tensorflow as tf
from tensorflow.keras import layers, applications, callbacks
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
import os
from focal_loss import SparseCategoricalFocalLoss
import gc
# Out:
# 2025-12-30 16:33:42.594215: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767112422.794569      47 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767112422.858703      47 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
SEED = 24520152

# %%
tf.keras.utils.set_random_seed(SEED)

# %%
TRAIN_DIR = '/kaggle/input/5-fold-brain-tumor-contrast-enhanced/kfold_dataset'
TRAIN_DIR
# Out:
# '/kaggle/input/5-fold-brain-tumor-contrast-enhanced/kfold_dataset'

# %%
SAVE_DIR = '/kaggle/working/'
SAVE_DIR
# Out:
# '/kaggle/working/'

# %%
CLASS_NAMES = sorted([d for d in os.listdir(os.path.join(TRAIN_DIR, 'Subset_1')) if os.path.isdir(os.path.join(TRAIN_DIR, 'Subset_1', d))])
CLASS_NAMES
# Out:
# ['Glioma Tumor', 'Meningioma Tumor', 'Pituitary Tumor']

# %%
MODEL1_DIR = '/kaggle/input/densenet121-ensemble/DenseNet121_Ensemble'
MODEL1_DIR
# Out:
# '/kaggle/input/densenet121-ensemble/DenseNet121_Ensemble'

# %%
preprocess_fn1 = applications.densenet.preprocess_input

# %%
MODEL2_DIR = '/kaggle/input/mobilenet-ensemble/MobileNet_Ensemble'
MODEL2_DIR
# Out:
# '/kaggle/input/mobilenet-ensemble/MobileNet_Ensemble'

# %%
preprocess_fn2 = applications.mobilenet.preprocess_input

# %%
MODEL3_DIR = '/kaggle/input/vgg19-ensemble/VGG19_Ensemble'
MODEL3_DIR
# Out:
# '/kaggle/input/vgg19-ensemble/VGG19_Ensemble'

# %%
preprocess_fn3 = applications.vgg19.preprocess_input

# %%
MODEL4_DIR = '/kaggle/input/xception-ensemble/Xception_Ensemble'
MODEL4_DIR
# Out:
# '/kaggle/input/xception-ensemble/Xception_Ensemble'

# %%
preprocess_fn4 = applications.xception.preprocess_input

# %%
def get_validation_fold(k, train_dir=TRAIN_DIR, IMG_SIZE=(224, 224), BATCH_SIZE=32, SEED=24520152):
    val_dir = os.path.join(train_dir, f'Subset_{k}')
    
    val_ds = tf.keras.utils.image_dataset_from_directory(
        val_dir,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        shuffle=False,
        seed=SEED,
    )
    
    AUTOTUNE = tf.data.AUTOTUNE

    return val_ds

# %%
def test(val_ds, fold_k, save_dir=SAVE_DIR, class_names=CLASS_NAMES):
    model1 = tf.keras.models.load_model(os.path.join(MODEL1_DIR, f'DenseNet121_block_2_fold_{fold_k}.keras'))
    model2 = tf.keras.models.load_model(os.path.join(MODEL2_DIR, f'MobileNet_block_1_fold_{fold_k}.keras'))
    model3 = tf.keras.models.load_model(os.path.join(MODEL3_DIR, f'VGG19_block_1_fold_{fold_k}.keras'))
    model4 = tf.keras.models.load_model(os.path.join(MODEL4_DIR, f'Xception_block_2_fold_{fold_k}.keras'))

    AUTOTUNE = tf.data.AUTOTUNE
    val_ds1 = val_ds.map(lambda image, label: (preprocess_fn1(image), label)).prefetch(buffer_size=AUTOTUNE)
    val_ds2 = val_ds.map(lambda image, label: (preprocess_fn2(image), label)).prefetch(buffer_size=AUTOTUNE)
    val_ds3 = val_ds.map(lambda image, label: (preprocess_fn3(image), label)).prefetch(buffer_size=AUTOTUNE)
    val_ds4 = val_ds.map(lambda image, label: (preprocess_fn4(image), label)).prefetch(buffer_size=AUTOTUNE)

    y_true = np.concatenate([y.numpy() for _, y in val_ds], axis=0)
    pred1 = model1.predict(val_ds1)
    pred2 = model2.predict(val_ds2)
    pred3 = model3.predict(val_ds3)
    pred4 = model4.predict(val_ds4)
    ensemble_pred = (pred1 + pred2 + pred3 + pred4) / 4.0
    y_pred = np.argmax(ensemble_pred, axis=1)
    print(classification_report(y_true, y_pred, target_names=class_names))
    
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix — Ensemble VGG19 - DenseNet121 - Xception - MobileNet')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    acc = accuracy_score(y_true, y_pred)

    del model1, model2, model3, model4, val_ds1, val_ds2, val_ds3, val_ds4, y_true, pred1, pred2, pred3, pred4, ensemble_pred, y_pred, cm
    tf.keras.backend.clear_session()
    gc.collect()

    return acc

# %%
acc = []

# %%
for fold_k in range(1, 6):
    print(f'Fold: {fold_k}')
    
    val_ds = get_validation_fold(fold_k)
    acc.append(test(val_ds, fold_k))

    del val_ds
    tf.keras.backend.clear_session()
    gc.collect()
# Out:
# Fold: 1
# Found 542 files belonging to 3 classes.
# I0000 00:00:1767112438.078159      47 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767112457.451217     116 service.cc:148] XLA service 0x7c4714003ec0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1767112457.452045     116 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1767112458.743108     116 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  3/17 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# I0000 00:00:1767112468.069486     116 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 29s 888ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 15s 476ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 360ms/step
#                   precision    recall  f1-score   support
#
#     Glioma Tumor       0.99      0.99      0.99       245
# Meningioma Tumor       0.96      0.97      0.96       112
#  Pituitary Tumor       1.00      0.98      0.99       185
#
#         accuracy                           0.99       542
#        macro avg       0.98      0.98      0.98       542
#     weighted avg       0.99      0.99      0.99       542
# Fold: 2
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 23s 654ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step
#                   precision    recall  f1-score   support
#
#     Glioma Tumor       0.95      0.92      0.94       338
# Meningioma Tumor       0.86      0.87      0.87       167
#  Pituitary Tumor       0.93      0.97      0.95       174
#
#         accuracy                           0.92       679
#        macro avg       0.92      0.92      0.92       679
#     weighted avg       0.92      0.92      0.92       679
# Fold: 3
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 24s 853ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 469ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 394ms/step
#                   precision    recall  f1-score   support
#
#     Glioma Tumor       0.96      0.90      0.93       231
# Meningioma Tumor       0.85      0.88      0.86       139
#  Pituitary Tumor       0.96      1.00      0.98       202
#
#         accuracy                           0.93       572
#        macro avg       0.92      0.93      0.92       572
#     weighted avg       0.93      0.93      0.93       572
# Fold: 4
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 745ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 352ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 308ms/step
#                   precision    recall  f1-score   support
#
#     Glioma Tumor       0.98      1.00      0.99       325
# Meningioma Tumor       0.95      0.88      0.91       124
#  Pituitary Tumor       0.94      0.96      0.95       179
#
#         accuracy                           0.96       628
#        macro avg       0.96      0.95      0.95       628
#     weighted avg       0.96      0.96      0.96       628
# Fold: 5
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 22s 658ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 210ms/step
#                   precision    recall  f1-score   support
#
#     Glioma Tumor       0.96      0.91      0.94       287
# Meningioma Tumor       0.84      0.70      0.77       166
#  Pituitary Tumor       0.82      0.99      0.90       190
#
#         accuracy                           0.88       643
#        macro avg       0.87      0.87      0.87       643
#     weighted avg       0.89      0.88      0.88       643

# %%
print(f'Accuracy: {np.mean(acc) * 100:.2f}%')
# Out:
# Accuracy: 93.78%
