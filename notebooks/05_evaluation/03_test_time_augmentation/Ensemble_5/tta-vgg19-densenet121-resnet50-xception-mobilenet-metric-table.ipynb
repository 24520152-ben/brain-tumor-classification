# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score
import os
from tensorflow.keras import layers, applications
# Out:
# 2026-01-04 12:50:55.770539: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767531055.961025      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767531056.016316      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767531056.446738      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767531056.446775      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767531056.446778      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767531056.446780      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
MODEL1_DIR = '/kaggle/input/densenet121-ensemble/DenseNet121_Ensemble'
preprocess_fn1 = applications.densenet.preprocess_input

MODEL2_DIR = '/kaggle/input/resnet50-ensemble/ResNet50_Ensemble'
preprocess_fn2 = applications.resnet.preprocess_input

MODEL3_DIR = '/kaggle/input/vgg19-ensemble/VGG19_Ensemble'
preprocess_fn3 = applications.vgg19.preprocess_input

MODEL4_DIR = '/kaggle/input/xception-ensemble/Xception_Ensemble'
preprocess_fn4 = applications.xception.preprocess_input

MODEL5_DIR = '/kaggle/input/mobilenet-ensemble/MobileNet_Ensemble'
preprocess_fn5 = applications.mobilenet.preprocess_input

# %%
TRAIN_DIR = '/kaggle/input/5-fold-brain-tumor-contrast-enhanced/kfold_dataset'

# %%
def tta_augmentation(img):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, 0.1)
    img = tf.image.random_contrast(img, lower=0.9, upper=1.1)
    return img

# %%
def tta_predict(model, preprocess_fn, ds, tta_rounds=5):
    AUTOTUNE = tf.data.AUTOTUNE
    
    val_ds = ds.map(lambda image, label: (preprocess_fn(image), label)).prefetch(AUTOTUNE)
    preds = [model.predict(val_ds)]

    for _ in range(tta_rounds):
        tta_ds = ds.map(lambda image, label: (tta_augmentation(image), label)).prefetch(AUTOTUNE)
        tta_ds = tta_ds.map(lambda image, label: (preprocess_fn(image), label)).prefetch(AUTOTUNE)
        preds.append(model.predict(tta_ds))

    preds = np.array(preds)
    return np.mean(preds, axis=0)

# %%
def get_pred_for_ensembling_model(fold_k, val_ds):
    model1 = tf.keras.models.load_model(os.path.join(MODEL1_DIR, f'DenseNet121_block_2_fold_{fold_k}.keras'), compile=False)
    model2 = tf.keras.models.load_model(os.path.join(MODEL2_DIR, f'ResNet50_block_1_fold_{fold_k}.keras'), compile=False)
    model3 = tf.keras.models.load_model(os.path.join(MODEL3_DIR, f'VGG19_block_1_fold_{fold_k}.keras'), compile=False)
    model4 = tf.keras.models.load_model(os.path.join(MODEL4_DIR, f'Xception_block_2_fold_{fold_k}.keras'), compile=False)
    model5 = tf.keras.models.load_model(os.path.join(MODEL5_DIR, f'MobileNet_block_1_fold_{fold_k}.keras'), compile=False)

    y_true = np.concatenate([y.numpy() for _, y in val_ds], axis=0)
    pred1 = tta_predict(model1, preprocess_fn1, val_ds)
    pred2 = tta_predict(model2, preprocess_fn2, val_ds)
    pred3 = tta_predict(model3, preprocess_fn3, val_ds)
    pred4 = tta_predict(model4, preprocess_fn4, val_ds)
    pred5 = tta_predict(model5, preprocess_fn5, val_ds)
    ensemble_pred = (pred1 + pred2 + pred3 + pred4 + pred5) / 5.0

    return ensemble_pred

# %%
DATASET_CACHE = {}
def get_validation_fold(k, train_dir=TRAIN_DIR, IMG_SIZE=(224, 224), BATCH_SIZE=32, SEED=24520152):
    val_dir = os.path.join(train_dir, f'Subset_{k}')
    
    val_ds = tf.keras.utils.image_dataset_from_directory(
        val_dir,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        shuffle=False,
        seed=SEED,
    )
    
    AUTOTUNE = tf.data.AUTOTUNE

    return val_ds

# %%
def get_predictions_for_fold(k):
    valid_data = get_validation_fold(k)

    y_true = []
    for _, y in valid_data:
        y_true.extend(y.numpy())
    y_true = np.array(y_true)
    y_pred = []

    y_pred.append(get_pred_for_ensembling_model(k, valid_data))
    
    y_pred = np.array(y_pred)
    return y_true, y_pred

# %%
def macro_specificity(y_true, y_pred, num_classes):
    cm = confusion_matrix(y_true, y_pred)
    spec = []

    for i in range(num_classes):
        TP = cm[i, i]
        FN = cm[i, :].sum() - TP
        FP = cm[:, i].sum() - TP
        TN = cm.sum() - (TP + FN + FP)

        spec.append(TN / (TN + FP + 1e-8))

    return np.array(spec)

# %%
def evaluate_fold(k):
    y_true, y_pred = get_predictions_for_fold(k)

    model_results = []
    for i in range(len(y_pred)):
        y_pred_label = np.argmax(y_pred[i], axis=1)
        acc = accuracy_score(y_true, y_pred_label)
        precision = precision_score(y_true, y_pred_label, average='macro', zero_division=0)
        recall = recall_score(y_true, y_pred_label, average='macro', zero_division=0)
        f1 = f1_score(y_true, y_pred_label, average='macro', zero_division=0)
        spec_per_class = macro_specificity(y_true, y_pred_label, 3)
        specificity = np.mean(spec_per_class)

        model_results.append({
            'Accuracy': np.array(acc),
            'Precision': np.array(precision),
            'Recall': np.array(recall),
            'F1-Score': np.array(f1),
            'Specificity': np.array(specificity)
        })
    return np.array(model_results)

# %%
num_run = 5
num_fold = 5
num_model = 1
metric_names = ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'Specificity']
all_result = []

for i in range(num_run):
    for j in range(1, 6):
        result = evaluate_fold(j)
        all_result.append(result)

all_result = np.array(all_result)
avg_metrics = {}

for m in range(num_model):
    avg_metrics[m] = {}
    for metric in metric_names:
        values = np.array([
            all_result[k][m][metric] for k in range(len(all_result))
        ])
        avg_metrics[m][metric] = values.mean(axis=0)*100
# Out:
# Found 542 files belonging to 3 classes.
# I0000 00:00:1767531069.855897      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767531090.988324     126 service.cc:152] XLA service 0x7ec0e8003950 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1767531090.988363     126 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1767531092.789318     126 cuda_dnn.cc:529] Loaded cuDNN version 91002
#  4/17 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# I0000 00:00:1767531103.367253     126 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 32s 986ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 361ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 15s 478ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 630ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 296ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 755ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 261ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 417ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 27s 913ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 340ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 472ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 665ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 278ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 27s 855ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 301ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 353ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 531ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 26s 703ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 10s 278ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 433ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 766ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 301ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 24s 575ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 222ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 252ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 24s 704ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 268ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 308ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 697ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 246ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 264ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 583ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 232ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 254ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 743ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 271ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 306ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 24s 576ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 225ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 247ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 25s 734ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 268ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 313ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 27s 783ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 266ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 161ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 578ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 237ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 258ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 758ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 308ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 24s 583ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 225ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 241ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 23s 689ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 301ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 711ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 247ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 264ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 164ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 576ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 253ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 742ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 274ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 301ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 24s 603ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 235ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 246ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 25s 741ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 269ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 286ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 715ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 251ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 264ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 589ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 266ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step

# %%
row_names = ['tta-densenet121-resnet50-xception-mobilenet']
column_names = ['Recall', 'Specificity', 'Precision', 'F1-Score', 'Accuracy']

df_result = pd.DataFrame(avg_metrics).T
df_result.index = row_names
df_result = df_result[column_names]
df_result = df_result.round(2)
df_result
# Out:
#                                              Recall  Specificity  Precision  \
# tta-densenet121-resnet50-xception-mobilenet    93.1         97.0      93.42
#
#                                              F1-Score  Accuracy
# tta-densenet121-resnet50-xception-mobilenet     93.14     94.03

# %%
latex_table = df_result.to_latex(
    multicolumn=True,
    multirow=True,
    float_format="%.2f",
    label="tab:sens_spec"
)

print(latex_table)
# Out:
# \begin{table}
# \label{tab:sens_spec}
# \begin{tabular}{lrrrrr}
# \toprule
#  & Recall & Specificity & Precision & F1-Score & Accuracy \\
# \midrule
# tta-densenet121-resnet50-xception-mobilenet & 93.10 & 97.00 & 93.42 & 93.14 & 94.03 \\
# \bottomrule
# \end{tabular}
# \end{table}
