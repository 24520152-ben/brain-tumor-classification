# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score
import os
from tensorflow.keras import layers, applications
# Out:
# 2026-01-04 12:05:57.745082: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767528357.921967      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767528357.973022      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767528358.405136      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767528358.405191      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767528358.405193      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767528358.405196      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
MODEL1_DIR = '/kaggle/input/densenet121-ensemble/DenseNet121_Ensemble'
preprocess_fn1 = applications.densenet.preprocess_input

MODEL2_DIR = '/kaggle/input/resnet50-ensemble/ResNet50_Ensemble'
preprocess_fn2 = applications.resnet.preprocess_input

MODEL3_DIR = '/kaggle/input/vgg19-ensemble/VGG19_Ensemble'
preprocess_fn3 = applications.vgg19.preprocess_input

MODEL4_DIR = '/kaggle/input/xception-ensemble/Xception_Ensemble'
preprocess_fn4 = applications.xception.preprocess_input

MODEL5_DIR = '/kaggle/input/mobilenet-ensemble/MobileNet_Ensemble'
preprocess_fn5 = applications.mobilenet.preprocess_input

# %%
TRAIN_DIR = '/kaggle/input/5-fold-brain-tumor-contrast-enhanced/kfold_dataset'

# %%
def tta_augmentation(img):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, 0.1)
    img = tf.image.random_contrast(img, lower=0.9, upper=1.1)
    return img

# %%
def tta_predict(model, preprocess_fn, ds, tta_rounds=5):
    AUTOTUNE = tf.data.AUTOTUNE
    
    val_ds = ds.map(lambda image, label: (preprocess_fn(image), label)).prefetch(AUTOTUNE)
    preds = [model.predict(val_ds)]

    for _ in range(tta_rounds):
        tta_ds = ds.map(lambda image, label: (tta_augmentation(image), label)).prefetch(AUTOTUNE)
        tta_ds = tta_ds.map(lambda image, label: (preprocess_fn(image), label)).prefetch(AUTOTUNE)
        preds.append(model.predict(tta_ds))

    preds = np.array(preds)
    return np.mean(preds, axis=0)

# %%
def get_pred_for_ensembling_model(fold_k, val_ds):
    model1 = tf.keras.models.load_model(os.path.join(MODEL1_DIR, f'DenseNet121_block_2_fold_{fold_k}.keras'), compile=False)
    model2 = tf.keras.models.load_model(os.path.join(MODEL2_DIR, f'ResNet50_block_1_fold_{fold_k}.keras'), compile=False)
    # model3 = tf.keras.models.load_model(os.path.join(MODEL3_DIR, f'VGG19_block_1_fold_{fold_k}.keras'), compile=False)
    model4 = tf.keras.models.load_model(os.path.join(MODEL4_DIR, f'Xception_block_2_fold_{fold_k}.keras'), compile=False)
    model5 = tf.keras.models.load_model(os.path.join(MODEL5_DIR, f'MobileNet_block_1_fold_{fold_k}.keras'), compile=False)

    y_true = np.concatenate([y.numpy() for _, y in val_ds], axis=0)
    pred1 = tta_predict(model1, preprocess_fn1, val_ds)
    pred2 = tta_predict(model2, preprocess_fn2, val_ds)
    # pred3 = tta_predict(model3, preprocess_fn3, val_ds)
    pred4 = tta_predict(model4, preprocess_fn4, val_ds)
    pred5 = tta_predict(model5, preprocess_fn5, val_ds)
    ensemble_pred = (pred1 + pred2 + pred4 + pred5) / 4.0

    return ensemble_pred

# %%
DATASET_CACHE = {}
def get_validation_fold(k, train_dir=TRAIN_DIR, IMG_SIZE=(224, 224), BATCH_SIZE=32, SEED=24520152):
    val_dir = os.path.join(train_dir, f'Subset_{k}')
    
    val_ds = tf.keras.utils.image_dataset_from_directory(
        val_dir,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        shuffle=False,
        seed=SEED,
    )
    
    AUTOTUNE = tf.data.AUTOTUNE

    return val_ds

# %%
def get_predictions_for_fold(k):
    valid_data = get_validation_fold(k)

    y_true = []
    for _, y in valid_data:
        y_true.extend(y.numpy())
    y_true = np.array(y_true)
    y_pred = []

    y_pred.append(get_pred_for_ensembling_model(k, valid_data))
    
    y_pred = np.array(y_pred)
    return y_true, y_pred

# %%
def macro_specificity(y_true, y_pred, num_classes):
    cm = confusion_matrix(y_true, y_pred)
    spec = []

    for i in range(num_classes):
        TP = cm[i, i]
        FN = cm[i, :].sum() - TP
        FP = cm[:, i].sum() - TP
        TN = cm.sum() - (TP + FN + FP)

        spec.append(TN / (TN + FP + 1e-8))

    return np.array(spec)

# %%
def evaluate_fold(k):
    y_true, y_pred = get_predictions_for_fold(k)

    model_results = []
    for i in range(len(y_pred)):
        y_pred_label = np.argmax(y_pred[i], axis=1)
        acc = accuracy_score(y_true, y_pred_label)
        precision = precision_score(y_true, y_pred_label, average='macro', zero_division=0)
        recall = recall_score(y_true, y_pred_label, average='macro', zero_division=0)
        f1 = f1_score(y_true, y_pred_label, average='macro', zero_division=0)
        spec_per_class = macro_specificity(y_true, y_pred_label, 3)
        specificity = np.mean(spec_per_class)

        model_results.append({
            'Accuracy': np.array(acc),
            'Precision': np.array(precision),
            'Recall': np.array(recall),
            'F1-Score': np.array(f1),
            'Specificity': np.array(specificity)
        })
    return np.array(model_results)

# %%
num_run = 5
num_fold = 5
num_model = 1
metric_names = ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'Specificity']
all_result = []

for i in range(num_run):
    for j in range(1, 6):
        result = evaluate_fold(j)
        all_result.append(result)

all_result = np.array(all_result)
avg_metrics = {}

for m in range(num_model):
    avg_metrics[m] = {}
    for metric in metric_names:
        values = np.array([
            all_result[k][m][metric] for k in range(len(all_result))
        ])
        avg_metrics[m][metric] = values.mean(axis=0)*100
# Out:
# Found 542 files belonging to 3 classes.
# I0000 00:00:1767528371.422650      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767528391.927836     128 service.cc:152] XLA service 0x7fae5c004e30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1767528391.927875     128 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1767528393.629826     128 cuda_dnn.cc:529] Loaded cuDNN version 91002
#  3/17 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# I0000 00:00:1767528404.235631     128 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 32s 959ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 621ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 275ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 718ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 257ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 416ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 27s 909ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 355ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 636ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 27s 793ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 296ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 523ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 26s 712ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 262ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 427ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 732ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 299ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 25s 594ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 225ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 243ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 24s 687ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 259ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 290ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 631ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 239ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 258ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 588ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 232ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 251ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 729ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 273ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 301ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 25s 578ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 222ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 242ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 24s 703ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 633ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 254ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 260ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 671ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 237ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 251ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 726ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 297ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 25s 586ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 222ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 243ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 24s 713ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 265ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 289ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 632ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 256ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 266ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 26s 609ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 235ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 254ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 744ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 278ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 302ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 26s 590ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 246ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 24s 720ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 289ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 642ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 258ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 264ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 26s 614ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 231ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 251ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step

# %%
row_names = ['tta-densenet121-resnet50-xception-mobilenet']
column_names = ['Recall', 'Specificity', 'Precision', 'F1-Score', 'Accuracy']

df_result = pd.DataFrame(avg_metrics).T
df_result.index = row_names
df_result = df_result[column_names]
df_result = df_result.round(2)
df_result
# Out:
#                                              Recall  Specificity  Precision  \
# tta-densenet121-resnet50-xception-mobilenet    92.4         96.7      92.92
#
#                                              F1-Score  Accuracy
# tta-densenet121-resnet50-xception-mobilenet      92.5     93.52

# %%
latex_table = df_result.to_latex(
    multicolumn=True,
    multirow=True,
    float_format="%.2f",
    label="tab:sens_spec"
)

print(latex_table)
# Out:
# \begin{table}
# \label{tab:sens_spec}
# \begin{tabular}{lrrrrr}
# \toprule
#  & Recall & Specificity & Precision & F1-Score & Accuracy \\
# \midrule
# tta-densenet121-resnet50-xception-mobilenet & 92.40 & 96.70 & 92.92 & 92.50 & 93.52 \\
# \bottomrule
# \end{tabular}
# \end{table}
