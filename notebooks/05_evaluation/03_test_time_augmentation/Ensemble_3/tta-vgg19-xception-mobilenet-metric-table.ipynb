# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score
import os
from tensorflow.keras import layers, applications
# Out:
# 2026-01-05 00:21:48.782426: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767572508.962325      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767572509.015079      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767572509.457026      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767572509.457082      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767572509.457086      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767572509.457089      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
MODEL1_DIR = '/kaggle/input/densenet121-ensemble/DenseNet121_Ensemble'
preprocess_fn1 = applications.densenet.preprocess_input

MODEL2_DIR = '/kaggle/input/resnet50-ensemble/ResNet50_Ensemble'
preprocess_fn2 = applications.resnet.preprocess_input

MODEL3_DIR = '/kaggle/input/vgg19-ensemble/VGG19_Ensemble'
preprocess_fn3 = applications.vgg19.preprocess_input

MODEL4_DIR = '/kaggle/input/xception-ensemble/Xception_Ensemble'
preprocess_fn4 = applications.xception.preprocess_input

MODEL5_DIR = '/kaggle/input/mobilenet-ensemble/MobileNet_Ensemble'
preprocess_fn5 = applications.mobilenet.preprocess_input

# %%
TRAIN_DIR = '/kaggle/input/5-fold-brain-tumor-contrast-enhanced/kfold_dataset'

# %%
def tta_augmentation(img):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, 0.1)
    img = tf.image.random_contrast(img, lower=0.9, upper=1.1)
    return img

# %%
def tta_predict(model, preprocess_fn, ds, tta_rounds=5):
    AUTOTUNE = tf.data.AUTOTUNE
    
    val_ds = ds.map(lambda image, label: (preprocess_fn(image), label)).prefetch(AUTOTUNE)
    preds = [model.predict(val_ds)]

    for _ in range(tta_rounds):
        tta_ds = ds.map(lambda image, label: (tta_augmentation(image), label)).prefetch(AUTOTUNE)
        tta_ds = tta_ds.map(lambda image, label: (preprocess_fn(image), label)).prefetch(AUTOTUNE)
        preds.append(model.predict(tta_ds))

    preds = np.array(preds)
    return np.mean(preds, axis=0)

# %%
def get_pred_for_ensembling_model(fold_k, val_ds):
    # model1 = tf.keras.models.load_model(os.path.join(MODEL1_DIR, f'DenseNet121_block_2_fold_{fold_k}.keras'), compile=False)
    # model2 = tf.keras.models.load_model(os.path.join(MODEL2_DIR, f'ResNet50_block_1_fold_{fold_k}.keras'), compile=False)
    model3 = tf.keras.models.load_model(os.path.join(MODEL3_DIR, f'VGG19_block_1_fold_{fold_k}.keras'), compile=False)
    model4 = tf.keras.models.load_model(os.path.join(MODEL4_DIR, f'Xception_block_2_fold_{fold_k}.keras'), compile=False)
    model5 = tf.keras.models.load_model(os.path.join(MODEL5_DIR, f'MobileNet_block_1_fold_{fold_k}.keras'), compile=False)

    y_true = np.concatenate([y.numpy() for _, y in val_ds], axis=0)
    # pred1 = tta_predict(model1, preprocess_fn1, val_ds)
    # pred2 = tta_predict(model2, preprocess_fn2, val_ds)
    pred3 = tta_predict(model3, preprocess_fn3, val_ds)
    pred4 = tta_predict(model4, preprocess_fn4, val_ds)
    pred5 = tta_predict(model5, preprocess_fn5, val_ds)
    ensemble_pred = (pred3 + pred4 + pred5) / 3.0

    return ensemble_pred

# %%
DATASET_CACHE = {}
def get_validation_fold(k, train_dir=TRAIN_DIR, IMG_SIZE=(224, 224), BATCH_SIZE=32, SEED=24520152):
    val_dir = os.path.join(train_dir, f'Subset_{k}')
    
    val_ds = tf.keras.utils.image_dataset_from_directory(
        val_dir,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        shuffle=False,
        seed=SEED,
    )
    
    AUTOTUNE = tf.data.AUTOTUNE

    return val_ds

# %%
def get_predictions_for_fold(k):
    valid_data = get_validation_fold(k)

    y_true = []
    for _, y in valid_data:
        y_true.extend(y.numpy())
    y_true = np.array(y_true)
    y_pred = []

    y_pred.append(get_pred_for_ensembling_model(k, valid_data))
    
    y_pred = np.array(y_pred)
    return y_true, y_pred

# %%
def macro_specificity(y_true, y_pred, num_classes):
    cm = confusion_matrix(y_true, y_pred)
    spec = []

    for i in range(num_classes):
        TP = cm[i, i]
        FN = cm[i, :].sum() - TP
        FP = cm[:, i].sum() - TP
        TN = cm.sum() - (TP + FN + FP)

        spec.append(TN / (TN + FP + 1e-8))

    return np.array(spec)

# %%
def evaluate_fold(k):
    y_true, y_pred = get_predictions_for_fold(k)

    model_results = []
    for i in range(len(y_pred)):
        y_pred_label = np.argmax(y_pred[i], axis=1)
        acc = accuracy_score(y_true, y_pred_label)
        precision = precision_score(y_true, y_pred_label, average='macro', zero_division=0)
        recall = recall_score(y_true, y_pred_label, average='macro', zero_division=0)
        f1 = f1_score(y_true, y_pred_label, average='macro', zero_division=0)
        spec_per_class = macro_specificity(y_true, y_pred_label, 3)
        specificity = np.mean(spec_per_class)

        model_results.append({
            'Accuracy': np.array(acc),
            'Precision': np.array(precision),
            'Recall': np.array(recall),
            'F1-Score': np.array(f1),
            'Specificity': np.array(specificity)
        })
    return np.array(model_results)

# %%
num_run = 5
num_fold = 5
num_model = 1
metric_names = ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'Specificity']
all_result = []

for i in range(num_run):
    for j in range(1, 6):
        result = evaluate_fold(j)
        all_result.append(result)

all_result = np.array(all_result)
avg_metrics = {}

for m in range(num_model):
    avg_metrics[m] = {}
    for metric in metric_names:
        values = np.array([
            all_result[k][m][metric] for k in range(len(all_result))
        ])
        avg_metrics[m][metric] = values.mean(axis=0)*100
# Out:
# Found 542 files belonging to 3 classes.
# I0000 00:00:1767572523.035415      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767572534.207100     126 service.cc:152] XLA service 0x7841a000afb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1767572534.207134     126 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1767572534.560453     126 cuda_dnn.cc:529] Loaded cuDNN version 91002
#  2/17 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step
# I0000 00:00:1767572542.237288     126 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 479ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 615ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 282ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 411ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 472ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 641ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 281ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 354ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 533ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 416ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 301ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 177ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 241ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 286ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 291ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 252ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 307ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 177ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 243ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 259ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 253ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 298ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 183ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 242ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 329ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 260ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# Found 542 files belonging to 3 classes.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 299ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 185ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# Found 679 files belonging to 3 classes.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 245ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# Found 572 files belonging to 3 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 284ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# Found 628 files belonging to 3 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 262ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# Found 643 files belonging to 3 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 248ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step

# %%
row_names = ['tta-vgg19-xception-mobilenet']
column_names = ['Recall', 'Specificity', 'Precision', 'F1-Score', 'Accuracy']

df_result = pd.DataFrame(avg_metrics).T
df_result.index = row_names
df_result = df_result[column_names]
df_result = df_result.round(2)
df_result
# Out:
#                               Recall  Specificity  Precision  F1-Score  \
# tta-vgg19-xception-mobilenet   93.54        97.16       93.6     93.49
#
#                               Accuracy
# tta-vgg19-xception-mobilenet     94.26

# %%
latex_table = df_result.to_latex(
    multicolumn=True,
    multirow=True,
    float_format="%.2f",
    label="tab:sens_spec"
)

print(latex_table)
# Out:
# \begin{table}
# \label{tab:sens_spec}
# \begin{tabular}{lrrrrr}
# \toprule
#  & Recall & Specificity & Precision & F1-Score & Accuracy \\
# \midrule
# tta-vgg19-xception-mobilenet & 93.54 & 97.16 & 93.60 & 93.49 & 94.26 \\
# \bottomrule
# \end{tabular}
# \end{table}
